# %%
import pandas as pd
import pickle

# %%
with open('saved_vars/prices_for_all_tickers.pkl', 'rb') as f:  # 'rb' = read binary
    prices = pickle.load(f)

# %%
row = prices['AAT']
df = prices['AAT']

# %%
row = row.dropna(axis=1)

# %%
row.columns.levels
# Out:
# FrozenList([['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], ['AAT', 'ABC', 'ACNB', 'ADMA', 'AEPI', 'AHH', 'AKRX', 'ALIM', 'AMOT', 'AMRC', 'ANDE', 'ANF', 'APHB', 'ARQL', 'ATAX', 'AXAS', 'BECC', 'BF', 'BG', 'BIOS', 'BKH', 'BLMN', 'BMR', 'BOBE', 'BREW', 'BTN', 'BWFG', 'BWINB', 'CAFN', 'CAKE', 'CAPN', 'CCNI', 'CCRN', 'CDE', 'CDI', 'CGIX', 'CHK', 'CKP', 'CNNX', 'CONN', 'CPK', 'CRDA.', 'CRSO', 'CRTN', 'CSBB', 'CSBR', 'CTO', 'CVA', 'CWBC', 'CWGL', 'CXDO', 'DAIO', 'DAVE', 'DLA', 'DO', 'DOC', 'DRRX', 'DTE', 'EEI', 'EGLE', 'EGP', 'ELMD', 'EMES', 'ENV', 'EQM', 'ERI', 'ERII', 'ETP', 'EVHC', 'EXE', 'EXXI', 'FCCO', 'FIVN', 'FIX', 'FLPC', 'FMD', 'FNHM', 'FPI', 'FSFG', 'GEF', 'GID', 'GNCA', 'GNE', 'GNMK', 'GTWN', 'GTY', 'GUID', 'HAYN', 'HES', 'HLX', 'HNSN', 'INIS', 'ISR', 'ITUS', 'JMBA', 'JMP', 'JVA', 'KERX', 'KKD', 'KMI', ...]])

# %%
aat = row.loc[:, (slice(None), "AAT")]

# %%
aat = aat.apply(get_ticker_data_from_cache, axis=1, result_type='expand')

# %%
df2 = df.swaplevel(axis=1)
df2 = df2.sort_index(axis=1)
wanted = ['Close', 'High', 'Low', 'Open', 'Volume']
df2 = df2.loc[:, (slice(None), wanted)]
df_flat = df2.stack(level=0)[wanted]
# final structure: outer level = ticker, inner level = fields
df2
# Out:
# C:\Users\aaron\AppData\Local\Temp\ipykernel_19548\188718115.py:5: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_flat = df2.stack(level=0)[wanted]
# Ticker            AAT                                            ABC           \
# Price           Close       High        Low       Open  Volume Close High Low
# Date
# 2014-11-05  26.166605  26.423869  26.058283  26.349397  195700   NaN  NaN NaN
# 2014-11-06  25.949959  26.308776  25.889027  26.254613  143500   NaN  NaN NaN
# 2014-11-07  25.983809  26.105671  25.760393  25.997349  169500   NaN  NaN NaN
# 2014-11-10  26.180143  26.207225  26.017661  26.037971  151400   NaN  NaN NaN
# 2014-11-11  26.376474  26.410325  26.125980  26.234302  221100   NaN  NaN NaN
# ...
